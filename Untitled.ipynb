# %%
import nsetools

# %%
nse=nsetools.Nse()
x=nse.get_quote('ZOMATO')

# %%
from pprint import pprint
pprint(x)
# Out:
# {'adhocMargin': None,
#  'applicableMargin': 14.39,
#  'averagePrice': 136.8,
#  'basePrice': 136.85,
#  'bcEndDate': None,
#  'bcStartDate': None,
#  'buyPrice1': None,
#  'buyPrice2': None,
#  'buyPrice3': None,
#  'buyPrice4': None,
#  'buyPrice5': None,
#  'buyQuantity1': None,
#  'buyQuantity2': None,
#  'buyQuantity3': None,
#  'buyQuantity4': None,
#  'buyQuantity5': None,
#  'change': '-0.05',
#  'closePrice': 136.6,
#  'cm_adj_high_dt': '14-SEP-21',
#  'cm_adj_low_dt': '23-JUL-21',
#  'cm_ffm': 9644.86,
#  'companyName': 'Zomato Limited',
#  'css_status_desc': 'Listed',
#  'dayHigh': 137.75,
#  'dayLow': 135.5,
#  'deliveryQuantity': 3151018.0,
#  'deliveryToTradedQuantity': 56.26,
#  'exDate': None,
#  'extremeLossMargin': 3.5,
#  'faceValue': 1.0,
#  'high52': 152.75,
#  'indexVar': None,
#  'isExDateFlag': False,
#  'isinCode': 'INE758T01015',
#  'lastPrice': 136.8,
#  'low52': 115.0,
#  'marketType': 'N',
#  'ndEndDate': None,
#  'ndStartDate': None,
#  'open': 137.3,
# ...

# %%
sorted(nse.get_stock_codes(),reverse=True)
# Out:
# ['ZYDUSWELL',
#  'ZUARIGLOB',
#  'ZUARI',
#  'ZOTA',
#  'ZOMATO',
#  'ZODIACLOTH',
#  'ZENTEC',
#  'ZENSARTECH',
#  'ZENITHSTL',
#  'ZENITHEXPO',
#  'ZEEMEDIA',
#  'ZEELEARN',
#  'ZEEL',
#  'YUKEN',
#  'YESBANK',
#  'YAARII',
#  'XPROINDIA',
#  'XELPMOC',
#  'XCHANGING',
#  'WSTCSTPAPR',
#  'WSI',
#  'WORTH',
#  'WONDERLA',
#  'WOCKPHARMA',
#  'WIPRO',
#  'WIPL',
#  'WINDMACHIN',
#  'WINDLAS',
#  'WILLAMAGOR',
#  'WHIRLPOOL',
#  'WHEELS',
#  'WESTLIFE',
#  'WENDT',
#  'WELSPUNIND',
#  'WELINV',
#  'WELENT',
#  'WELCORP',
#  'WEIZMANIND',
#  'WEBELSOLAR',
#  'WEALTH',
#  'WATERBASE',
#  'WANBURY',
#  'WALCHANNAG',
#  'WABCOINDIA',
#  'WABAG',
#  'VTL',
#  'VSTTILLERS',
#  'VSTIND',
#  'VSSL',
#  'VRLLOG',
#  'VOLTAS',
#  'VOLTAMP',
#  'VMART',
#  'VLSFINANCE',
#  'VIVIMEDLAB',
#  'VIVIDHA',
#  'VISHWARAJ',
#  'VISHNU',
#  'VISHAL',
#  'VISASTEEL',
#  'VISAKAIND',
#  'VIPULLTD',
#  'VIPIND',
#  'VIPCLOTHNG',
#  'VINYLINDIA',
#  'VINEETLAB',
#  'VINDHYATEL',
#  'VINATIORGA',
# ...

# %%
nse.is_valid_code('infy')
# Out:
# True

# %%
nse.get_top_fno_gainers()
# Out:
# [{'symbol': 'BATAINDIA',
#   'series': 'EQ',
#   'openPrice': 1971.8,
#   'highPrice': 2108.85,
#   'lowPrice': 1953.8,
#   'ltp': 2106.0,
#   'previousPrice': 1969.2,
#   'netPrice': 6.95,
#   'tradedQuantity': 1032850.0,
#   'turnoverInLakhs': 21075.82,
#   'lastCorpAnnouncementDate': '04-Aug-2021',
#   'lastCorpAnnouncement': 'Annual General Meeting/Dividend - Rs 4 Per Share'},
#  {'symbol': 'NATIONALUM',
#   'series': 'EQ',
#   'openPrice': 98.0,
#   'highPrice': 103.0,
#   'lowPrice': 97.0,
#   'ltp': 102.9,
#   'previousPrice': 96.35,
#   'netPrice': 6.8,
#   'tradedQuantity': 38450940.0,
#   'turnoverInLakhs': 38362.5,
#   'lastCorpAnnouncementDate': '23-Sep-2021',
#   'lastCorpAnnouncement': 'Annual General Meeting/Dividend - Re 1 Per Share'},
#  {'symbol': 'TITAN',
#   'series': 'EQ',
#   'openPrice': 2365.0,
#   'highPrice': 2507.8,
#   'lowPrice': 2342.65,
#   'ltp': 2506.0,
#   'previousPrice': 2362.4,
#   'netPrice': 6.08,
#   'tradedQuantity': 3517011.0,
# ...
